# %%
import pandas as pd

# %%
url = 'https://www.espncricinfo.com/records/most-sixes-in-a-match-283013'

# %%
all_tables = pd.read_html(url)

# %%
len(all_tables)
# Out:
# 1

# %%
all_tables[0]
# Out:
#           Team 1        Team 2  4s  6s  Unnamed: 4        Winner       Ground  \
# 0    West Indies       England  64  46         NaN       England  St George's
# 1          India     Australia  59  38         NaN         India    Bengaluru
# 2          India       England  44  34         NaN       England         Pune
# 3        England   Afghanistan  37  33         NaN       England   Manchester
# 4          India   New Zealand  56  32         NaN         India       Indore
# ..           ...           ...  ..  ..         ...           ...          ...
# 259      England   New Zealand  52  15         NaN   New Zealand      Cardiff
# 260     Pakistan     Sri Lanka  62  15         NaN      Pakistan    Hyderabad
# 261        India   Afghanistan  53  15         NaN         India        Delhi
# 262    Australia   Netherlands  55  15         NaN     Australia        Delhi
# 263  Afghanistan  South Africa  35  15         NaN  South Africa    Ahmedabad
#
#       Match Date   Scorecard
# ...

# %%
all_tables[0].to_csv('totalsixes_figure.csv',index=False)
